# %%
# Write your solution here
def xaloha(m):
    n = len(m)
    return n

# %% [markdown]
# What is the sound of one hand clapping?
# what is next?
# $ \int z e^{x^2} dx $
# Where do you go!
# def fact(n): return n
