# %%
from pprint import pprint

# %%
from sklearn.datasets import fetch_20newsgroups
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import classification_report, accuracy_score
from sklearn.pipeline import make_pipeline

# %%
cats = [ "alt.atheism",
    "soc.religion.christian",
    "comp.graphics",
    "sci.med"]

# %%
train = fetch_20newsgroups(subset='train', categories=cats)
test = fetch_20newsgroups(subset='test', categories=cats)

# %%
pipe = make_pipeline(
    CountVectorizer(),
    MultinomialNB(alpha=1)
)

# %%
pipe.fit(train.data, train.target)
# Out:
# Pipeline(steps=[('countvectorizer', CountVectorizer()),
#                 ('multinomialnb', MultinomialNB(alpha=1))])

# %%
pred = pipe.predict(test.data)
type(pred)
# Out:
# numpy.ndarray

# %%
pprint(accuracy_score(test.target, pred))
# Out:
# 0.9340878828229028

# %%
pprint(classification_report(test.target,pred,target_names=train.target_names))
# Out:
# ('                        precision    recall  f1-score   support\n'
#  '\n'
#  '           alt.atheism       0.92      0.90      0.91       319\n'
#  '         comp.graphics       0.95      0.95      0.95       389\n'
#  '               sci.med       0.96      0.91      0.93       396\n'
#  'soc.religion.christian       0.91      0.97      0.94       398\n'
#  '\n'
#  '              accuracy                           0.93      1502\n'
#  '             macro avg       0.93      0.93      0.93      1502\n'
#  '          weighted avg       0.93      0.93      0.93      1502\n')
